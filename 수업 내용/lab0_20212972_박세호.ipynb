# %%
print("Hello world!")
# Out:
# Hello world!

# %%
print("My name is Seho Park")
# Out:
# My name is Seho Park

# %% [markdown]
# 지금부터는 c언어로 해봅시다!

# %%
# %%writefile hello.c
# #include <stdio.h>
# int main(void)
# {
#   printf("Hello world!");
#
#   return 0;
# }
# Out:
# Overwriting hello.c

# %%
ls
# Out:
# hello.c  output*  sample_data/

# %%
# %%shell
# gcc hello.c -o output
# ./output
# Out:
# Hello world!
